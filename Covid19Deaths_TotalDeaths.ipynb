# %% [markdown]
# <a href="https://colab.research.google.com/github/EsraMutlugun/Jupyter_Data_Analysis_Projects/blob/main/Covid19Deaths_TotalDeaths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries and  CSV file
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1355637f-b775-472a-84d6-52c50a9d2339" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1355637f-b775-472a-84d6-52c50a9d2339">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Provisional_COVID-19_Death_Counts_by_Sex__Age__and_State.csv to Provisional_COVID-19_Death_Counts_by_Sex__Age__and_State (1).csv

# %%
# Read CSV file
df1 = pd.read_csv(io.BytesIO(uploaded['Provisional_COVID-19_Death_Counts_by_Sex__Age__and_State.csv']))

# %%
# Look at the column names
df1.columns
# Out:
# Index(['Data as of', 'Start week', 'End Week', 'State', 'Sex', 'Age group',
#        'COVID-19 Deaths', 'Total Deaths', 'Pneumonia Deaths',
#        'Pneumonia and COVID-19 Deaths', 'Influenza Deaths',
#        'Pneumonia, Influenza, or COVID-19 Deaths', 'Footnote'],
#       dtype='object')

# %%
# Look at first several lines of a files
df1.head()
# Out:
#    Data as of  Start week  ... Pneumonia, Influenza, or COVID-19 Deaths Footnote
# 0  12/02/2020  02/01/2020  ...                                 390588.0      NaN
# 1  12/02/2020  02/01/2020  ...                                    179.0      NaN
# 2  12/02/2020  02/01/2020  ...                                    637.0      NaN
# 3  12/02/2020  02/01/2020  ...                                    147.0      NaN
# 4  12/02/2020  02/01/2020  ...                                    210.0      NaN
#
# [5 rows x 13 columns]

# %%
#Look at the dataset columns and rows number
print(len(df1))
print(len(df1.columns))
# Out:
# 2661
# 13

# %%
# Take a look datatypes
df1.dtypes
# Out:
# Data as of                                   object
# Start week                                   object
# End Week                                     object
# State                                        object
# Sex                                          object
# Age group                                    object
# COVID-19 Deaths                             float64
# Total Deaths                                float64
# Pneumonia Deaths                            float64
# Pneumonia and COVID-19 Deaths               float64
# Influenza Deaths                            float64
# Pneumonia, Influenza, or COVID-19 Deaths    float64
# Footnote                                     object
# dtype: object

# %%
#Describe dataset
df1.describe()
# Out:
#        COVID-19 Deaths  ...  Pneumonia, Influenza, or COVID-19 Deaths
# count      2271.000000  ...                               2184.000000
# mean        837.077939  ...                               1366.733974
# std        7308.824445  ...                              11636.137460
# min           0.000000  ...                                  0.000000
# 25%           0.000000  ...                                  0.000000
# 50%           0.000000  ...                                 17.000000
# 75%         146.500000  ...                                297.250000
# max      249570.000000  ...                             390588.000000
#
# [8 rows x 6 columns]

# %%
#Cleaning some repeating rows 
indexNames = df1[ df1['Sex'] == 'All Sexes' ].index
df1.drop(indexNames , inplace=True)

# %%
#Cleaning some repeating rows 
indexNames2 = df1[ df1['Age group'] == 'All Ages' ].index
df1.drop(indexNames2 , inplace=True)

# %%
indexNames = df1[ df1['State'] == 'United States' ].index
df1.drop(indexNames , inplace=True)

# %%
# Take a look dataset mean values
df1.mean()
# Out:
# COVID-19 Deaths                              149.967532
# Total Deaths                                1497.766995
# Pneumonia Deaths                             158.510193
# Pneumonia and COVID-19 Deaths                 68.178536
# Influenza Deaths                               4.267606
# Pneumonia, Influenza, or COVID-19 Deaths     247.023474
# dtype: float64

# %%
#
name = df1['Age group']
number = df1['COVID-19 Deaths'] 
  
# Figure Size 
fig = plt.figure(figsize =(25, 15)) 
  
# Create a title
plt.title('Covid-19 Deaths by Age groups ')
# Horizontal Bar Plot 
plt.bar(name, number, color='magenta') 


# Show Plot 
plt.show()

# %%
name = df1['Age group']
price = df1['Pneumonia Deaths'] 
  
# Figure Size 
fig = plt.figure(figsize =(25, 12)) 

# Create a title
plt.title('Pneumonia Deaths by Age groups ')
  
# Horizontal Bar Plot 
plt.bar(name, price,color='turquoise') 
  
# Show Plot 
plt.show()

# %%
name = df1['Age group']
price = df1['Influenza Deaths'] 
  
# Figure Size 
fig = plt.figure(figsize =(25, 12)) 

# Create a title
plt.title('Influenza Deaths by Age groups ')
  
# Horizontal Bar Plot 
plt.bar(name, price,color='gold') 
  
# Show Plot 
plt.show()

# %%
plt.figure(figsize=(10,10))
 
plt.bar(x=df1['Sex'],
 
        height=df1['COVID-19 Deaths'], color='magenta')

plt.xticks(rotation=45,fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True)
plt.title('Covid-19 by Gender')
plt.show()

# %%
plt.figure(figsize=(10,10))
 
plt.bar(x=df1['Sex'],
 
        height=df1['Pneumonia Deaths'], color='turquoise')

plt.xticks(rotation=45,fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True)
plt.title('Pneumonia Deaths by Gender')
plt.show()

# %%
plt.figure(figsize=(10,10))
 
plt.bar(x=df1['Sex'],
 
        height=df1['Influenza Deaths'], color='gold')

plt.xticks(rotation=45,fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True)
plt.title('Influenza Deaths')
plt.show()

# %%
indexNames = df1[ df1['State'] == 'United States' ].index
df1.drop(indexNames , inplace=True)

# %%
import matplotlib.colors as mcolor
plt.figure(figsize=(50,20))
 
plt.bar(x=df1['State'],
 
        height=df1['COVID-19 Deaths'], color='magenta')
 
plt.xticks(rotation=45,fontsize=20)
plt.yticks(fontsize=20)
plt.grid(True)
plt.title('Total Covid-19 Deaths by State')
plt.show()

# %%
df1['percent_Covid']=df1['COVID-19 Deaths']/df1['Total Deaths']

# %%
plt.figure(figsize=(50,240))
 
plt.bar(x=df1['State'],
 
        height=df1['percent_Covid'], color='magenta')
 
plt.xticks(rotation=45,fontsize=20)
plt.yticks(fontsize=20)
plt.grid(True)
plt.title('Covid-19')
plt.show()

# %%
plt.figure(figsize =  (50,20))
plt.title("Have Most Total Deaths in the US", fontdict={'fontsize': 20})
sns.barplot(x = df1['State'], y =df1['Total Deaths'], data = df1, palette="plasma")
plt.show()

# %%
sns.set()
plt.figure(figsize =  (10,10))
plt.title("Relationship betwen COVID 19 - Influenza death", fontdict={'fontsize': 15})
sns.scatterplot(x =df1['COVID-19 Deaths'], y = df1['Age group'], data= df1, palette="plasma", hue = "Sex")
plt.show()

# %%
sns.set()
plt.figure(figsize =  (10,10))
plt.title("Relationship betwen COVID 19 - Influenza death", fontdict={'fontsize': 15})
sns.scatterplot(x =df1['Influenza Deaths'], y = df1['Age group'], data= df1, palette="tab10", hue = "Sex")
plt.show()

# %%
fig, ax = plt.subplots()
plt.gcf().set_size_inches((25, 10))
ax.bar("COVID-19 Deaths", df1["COVID-19 Deaths"].mean(), yerr=df1["COVID-19 Deaths"].std())
ax.bar("Influenza Deaths", df1["Influenza Deaths"].mean(), yerr=df1["Influenza Deaths"].std())
ax.bar("Pneumonia Deaths", df1["Pneumonia Deaths"].mean(), yerr=df1["Pneumonia Deaths"].std())
ax.bar("Total Deaths", df1["Total Deaths"].mean(), yerr=df1["Total Deaths"].std())
plt.title=('Covid 19 & Influenza & Pnemonia & Total Deaths')

# %%
plt.figure(figsize =  (20,10))
plt.legend
df1['COVID-19 Deaths'].diff().hist()
df1['Pneumonia Deaths'].diff().hist()
df1['Influenza Deaths'].diff().hist()
plt.legend(["Covid-19 Deaths", "Pneumonia Deaths","Influenza Deaths"])
plt.title='Covid-19, Influenza & Pneumonia Cases Comparison'
plt.show()

# %%
import seaborn as sns
plt.figure(figsize =  (50,20))
plt.title("Most infected states in US", fontdict={'fontsize': 20})
sns.barplot(x = df1['State'], y =df1['percent_Covid'], data = df1, palette="plasma")
plt.show()
